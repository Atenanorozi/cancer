# %% [markdown]
# # بخش اول
#
#
# # Determine Business Objectives

# %% [markdown]
# ### سوال 1
#
# مسئله اصلی کسب‌وکار را با زبان ساده توضیح دهید.

# %% [markdown]
# بیمارستان نیاز دارد بیماران در معرض خطر سرطان ریه را در سریع‌ترین زمان ممکن شناسایی کند تا درمان زودهنگام آغاز شود، هزینه‌های درمان کاهش یابد و احتمال بهبود بیماران افزایش پیدا کند.

# %% [markdown]
# ### سوال 2
#
# اگر این پروژه اجرا نشود چه مشکلاتی برای بیمارستان ایجاد خواهد شد؟

# %% [markdown]
# /تشخیص دیرهنگام سرطان ریه
# /افزایش هزینه‌های درمان
# /افزایش مرگ‌ومیر بیماران
# /افزایش زمان تصمیم‌گیری پزشکان
# /استفاده غیربهینه از منابع بیمارستان
# کاهش رضایت بیماران

# %% [markdown]
# ### سوال 3
#
# چه ذی‌نفعانی (Stakeholders) در این پروژه حضور دارند؟

# %% [markdown]
# /مدیر بیمارستان
# /پزشکان متخصص ریه و انکولوژی
# /پرستاران
# /بیماران
# /واحد فناوری اطلاعات (IT)
# /واحد آزمایشگاه
# /واحد تصویربرداری
# /تیم علم داده (Data Science)
# /کارشناسان ثبت اطلاعات پزشکی
# شرکت بیمه

# %% [markdown]
# ### سوال 4
#
# برای هر Stakeholder نیاز و انتظار او را مشخص کنید.

# %% [markdown]
# | Stakeholder    | نیاز                   | انتظار                  |
# | -------------- | ---------------------- | ----------------------- |
# | مدیر بیمارستان | کاهش هزینه‌ها          | افزایش کیفیت خدمات      |
# | پزشک           | تشخیص سریع و دقیق      | کمک در تصمیم‌گیری درمان |
# | پرستار         | اطلاع از بیماران پرخطر | برنامه‌ریزی بهتر مراقبت |
# | بیمار          | تشخیص سریع             | افزایش احتمال درمان     |
# | IT             | سیستم پایدار           | پیاده‌سازی آسان         |
# | آزمایشگاه      | دسترسی به نتایج        | ثبت صحیح اطلاعات        |
# | تیم علم داده   | داده باکیفیت           | ساخت مدل دقیق           |
# | بیمه           | کاهش هزینه درمان       | مدیریت بهتر هزینه‌ها    |

# %% [markdown]
# ### سوال 5
#
# هدف اصلی کسب‌وکار را در یک جمله بنویسید.

# %% [markdown]
# طراحی یک سیستم هوشمند برای پیش‌بینی سطح خطر سرطان ریه به منظور کمک به تشخیص زودهنگام و بهبود تصمیم‌گیری پزشکان.

# %% [markdown]
# ### سوال 6
#
# حداقل سه هدف فرعی برای این پروژه تعریف کنید.

# %% [markdown]
# /کاهش زمان تشخیص بیماران پرخطر.
# /افزایش دقت تصمیم‌گیری پزشکان.
# /کاهش هزینه‌های درمان از طریق تشخیص زودهنگام.
# /افزایش رضایت بیماران.
# بهینه‌سازی استفاده از منابع بیمارستان.

# %% [markdown]
# ### سوال 7
#
# چه شاخص‌هایی نشان می‌دهد پروژه موفق بوده است؟ (KPI)

# %% [markdown]
# موفقیت پروژه با بهبود دقت پیش‌بینی، کاهش زمان تشخیص، افزایش رضایت پزشکان و کاهش هزینه‌های درمان اندازه‌گیری می‌شود.

# %% [markdown]
# ### سوال 8
#
# حداقل پنج KPI برای این پروژه تعریف کنید.

# %% [markdown]
# | KPI                  | هدف          |
# | -------------------- | ------------ |
# | Accuracy مدل         | بیشتر از 90٪ |
# | Recall بیماران پرخطر | بیشتر از 95٪ |
# | کاهش زمان تشخیص      | حداقل 30٪    |
# | رضایت پزشکان         | بیشتر از 85٪ |
# | کاهش هزینه درمان     | حداقل 15٪    |

# %% [markdown]
# ### سوال 9
#
# موفقیت این پروژه از دید مدیر بیمارستان چگونه اندازه‌گیری می‌شود؟

# %% [markdown]
# /کاهش هزینه‌های درمان
# /افزایش بهره‌وری بیمارستان
# /افزایش کیفیت خدمات
# /کاهش مراجعات مجدد
# رضایت بیماران

# %% [markdown]
# ### سوال 10
#
# موفقیت این پروژه از دید پزشکان چگونه اندازه‌گیری می‌شود؟

# %% [markdown]
# /دقت بالای پیش‌بینی
# /کاهش خطاهای تشخیص
# /سرعت بیشتر در تصمیم‌گیری
# /ارائه نتایج قابل اعتماد
# سهولت استفاده از سیستم

# %% [markdown]
# ### سوال 11
#
# یک Business Objective Statement رسمی برای این پروژه بنویسید.

# %% [markdown]
# هدف این پروژه طراحی و پیاده‌سازی یک سیستم مبتنی بر داده‌کاوی برای پیش‌بینی سطح خطر سرطان ریه بیماران است تا با تشخیص زودهنگام، کیفیت تصمیم‌گیری پزشکان افزایش یافته، هزینه‌های درمان کاهش یابد و در نهایت کیفیت خدمات درمانی بیمارستان بهبود پیدا کند.

# %% [markdown]
# # بحش دوم
# # Assess Situation

# %% [markdown]
# ### سوال 12
#
# چه اطلاعاتی را قبل از شروع پروژه باید از بیمارستان دریافت کنید؟

# %% [markdown]
# هدف اصلی پروژه
# /اطلاعات بیماران
# /سوابق پزشکی بیماران
# /نتایج آزمایش‌ها
# /تصاویر پزشکی (در صورت وجود)
# /تعداد بیماران ثبت‌شده
# /نحوه ثبت داده‌ها
# /سیاست‌های محرمانگی اطلاعات
# /امکانات سخت‌افزاری و نرم‌افزاری بیمارستان
# انتظارات مدیران و پزشکان از سیستم

# %% [markdown]
# ### سوال 13
#
# حداقل 10 سوال که باید از مدیر بیمارستان بپرسید طراحی کنید.

# %% [markdown]
# مهم‌ترین مشکل بیمارستان در تشخیص سرطان ریه چیست؟
#
# هدف اصلی از اجرای این پروژه چیست؟
#
# چه میزان بودجه برای پروژه در نظر گرفته شده است؟
#
# چه زمانی انتظار دارید پروژه آماده بهره‌برداری شود؟
#
# چه معیارهایی برای موفقیت پروژه دارید؟
#
# آیا داده‌های بیماران کامل و به‌روز هستند؟
#
# آیا امکان اتصال سیستم به HIS بیمارستان وجود دارد؟
#
# چه تعداد بیمار در سال پذیرش می‌شوند؟
#
# آیا محدودیت قانونی برای استفاده از داده‌ها وجود دارد؟
#
# چه گزارش‌هایی برای مدیریت مورد نیاز است؟

# %% [markdown]
# ### سوال 14
#
# حداقل 10 سوال که باید از پزشکان بپرسید طراحی کنید.

# %% [markdown]
# مهم‌ترین علائم سرطان ریه از نظر شما چیست؟
#
# کدام ویژگی‌ها بیشترین تأثیر را در تشخیص دارند؟
#
# مهم‌ترین خطای قابل قبول در سیستم چیست؟
#
# آیا ترجیح می‌دهید احتمال بیماری نمایش داده شود یا سطح خطر؟
#
# سرعت پاسخ‌گویی سیستم چقدر اهمیت دارد؟
#
# آیا پزشک باید بتواند دلیل پیش‌بینی مدل را مشاهده کند؟
#
# چه عواملی باعث کاهش اعتماد به مدل می‌شوند؟
#
# آیا سیستم باید پیشنهاد درمان نیز ارائه دهد؟
#
# خروجی سیستم چگونه نمایش داده شود؟
#
# مهم‌ترین انتظار شما از این پروژه چیست؟

# %% [markdown]
# ### سوال 15
#
# محدودیت‌های احتمالی پروژه را فهرست کنید.

# %% [markdown]
# /کمبود داده
# /کیفیت پایین داده‌ها
# /محدودیت بودجه
# /محدودیت زمان
# /کمبود نیروی متخصص
# /محدودیت سخت‌افزاری
# /قوانین محرمانگی اطلاعات
# مقاومت کاربران در برابر سیستم جدید

# %% [markdown]
# ### سوال 16
#
# محدودیت‌های مالی پروژه را تحلیل کنید.

# %% [markdown]
# /هزینه جمع‌آوری داده
# /هزینه توسعه نرم‌افزار
# /هزینه آموزش کارکنان
# /هزینه نگهداری سیستم
# هزینه خرید سرور و تجهیزات

# %% [markdown]
# ### سوال 17
#
# محدودیت‌های فنی پروژه را تحلیل کنید.

# %% [markdown]
# /کیفیت پایین داده‌ها
# /ناسازگاری فرمت داده‌ها
# /محدودیت قدرت پردازشی
# /نبود داده‌های کافی برای آموزش مدل
# دشواری اتصال سیستم به سامانه‌های بیمارستان

# %% [markdown]
# ###  سوال 18
#
# مهم‌ترین ریسک‌های پروژه را شناسایی کنید.

# %% [markdown]
# /کیفیت پایین داده‌ها
# /کمبود داده
# /بیش‌برازش (Overfitting) مدل
# /عدم پذیرش سیستم توسط پزشکان
# /تأخیر در اجرای پروژه
# نشت اطلاعات بیماران

# %% [markdown]
# ### سوال 19
#
# برای هر ریسک احتمال وقوع و شدت اثر را تعیین کنید.

# %% [markdown]
# | ریسک              | احتمال | شدت اثر    |
# | ----------------- | ------ | ---------- |
# | کیفیت پایین داده  | زیاد   | زیاد       |
# | کمبود داده        | متوسط  | زیاد       |
# | Overfitting       | متوسط  | زیاد       |
# | عدم اعتماد پزشکان | زیاد   | زیاد       |
# | تأخیر پروژه       | متوسط  | متوسط      |
# | نشت اطلاعات       | کم     | بسیار زیاد |

# %% [markdown]
# ### سوال 20
#
# جدول Risk Assessment تهیه کنید.

# %% [markdown]
# | Risk              | Probability | Impact    | Priority |
# | ----------------- | ----------- | --------- | -------- |
# | کیفیت پایین داده  | High        | High      | High     |
# | عدم اعتماد پزشکان | High        | High      | High     |
# | کمبود داده        | Medium      | High      | High     |
# | تأخیر پروژه       | Medium      | Medium    | Medium   |
# | نشت اطلاعات       | Low         | Very High | High     |

# %% [markdown]
# ### سوال 21
#
# چه داده‌هایی احتمالاً برای این پروژه مورد نیاز خواهند بود؟

# %% [markdown]
# سن
#
# جنسیت
#
# سابقه مصرف سیگار
#
# مصرف الکل
#
# سابقه خانوادگی سرطان
#
# بیماری‌های ریوی
#
# سرفه مزمن
#
# تنگی نفس
#
# درد قفسه سینه
#
# نتایج آزمایش‌ها
#
# تصاویر CT Scan (در صورت وجود)
#
# متغیر هدف (Level)

# %% [markdown]
# ### سوال 22
#
# چه داده‌هایی ممکن است جمع‌آوری آن‌ها دشوار باشد؟

# %% [markdown]
# سابقه خانوادگی دقیق
#
# نتایج تصویربرداری
#
# اطلاعات ژنتیکی
#
# سوابق پزشکی بیمار در سایر مراکز
#
# اطلاعات سبک زندگی بیمار

# %% [markdown]
# ### سوال 23
#
# اگر داده‌های کافی وجود نداشته باشد چه راهکارهایی پیشنهاد می‌کنید؟

# %% [markdown]
# جمع‌آوری داده از بیمارستان‌های دیگر
#
# افزایش دوره جمع‌آوری داده
#
# استفاده از داده‌های معتبر عمومی
#
# استفاده از روش‌های Data Augmentation (در صورت مناسب بودن نوع داده)
#
# به‌روزرسانی مداوم دیتاست

# %% [markdown]
# ### سوال 24
#
# یک SWOT Analysis برای پروژه تهیه کنید.

# %% [markdown]
# | Strengths (نقاط قوت)  | Weaknesses (نقاط ضعف) |
# | --------------------- | --------------------- |
# | تشخیص سریع‌تر بیماران | وابستگی به کیفیت داده |
# | کاهش هزینه درمان      | نیاز به داده زیاد     |
# | کمک به پزشکان         | نیاز به آموزش کاربران |
#
# | Opportunities (فرصت‌ها)          | Threats (تهدیدها)       |
# | -------------------------------- | ----------------------- |
# | توسعه سیستم در سایر بیمارستان‌ها | حملات سایبری            |
# | افزایش کیفیت خدمات درمانی        | تغییر قوانین حریم خصوصی |
# | توسعه مدل‌های هوش مصنوعی         | عدم پذیرش توسط پزشکان   |

# %% [markdown]
# # بخش سوم
#
# # Determine Data Mining Goals

# %% [markdown]
# ### سوال 25
#
# هدف داده‌کاوی این پروژه چیست؟

# %% [markdown]
# هدف داده‌کاوی این پروژه، ساخت یک مدل یادگیری ماشین برای پیش‌بینی سطح خطر سرطان ریه (Level) بر اساس اطلاعات بیماران است تا پزشکان بتوانند بیماران پرخطر را سریع‌تر شناسایی کنند.

# %% [markdown]
# ### سوال 26
#
# تفاوت بین Business Goal و Data Mining Goal چیست؟

# %% [markdown]
# | Business Goal         | Data Mining Goal                    |
# | --------------------- | ----------------------------------- |
# | حل یک مسئله کسب‌وکاری | ساخت یک مدل داده‌کاوی برای حل مسئله |
# | کاهش هزینه‌های درمان  | پیش‌بینی دقیق سطح خطر سرطان ریه     |
# | افزایش کیفیت خدمات    | دستیابی به بهترین مدل طبقه‌بندی     |

# %% [markdown]
# ### سوال 27
#
# هدف داده‌کاوی پروژه را در یک جمله بنویسید.

# %% [markdown]
# طراحی و آموزش یک مدل طبقه‌بندی برای پیش‌بینی سطح خطر سرطان ریه (Low، Medium و High) با استفاده از ویژگی‌های بیماران.

# %% [markdown]
# ### سوال 28
#
# آیا این پروژه:
#
#     Classification
#     Regression
#     Clustering
#     Association Rule
#
# است؟
#
# دلایل خود را توضیح دهید.

# %% [markdown]
# Classification -> زیرا متغیر هدف (Level) شامل کلاس‌های مشخص Low، Medium و High است و هدف پروژه پیش‌بینی یکی از این کلاس‌ها برای هر بیمار است.

# %% [markdown]
# ### سوال 29
#
# اگر خروجی پروژه احتمال بیماری باشد، نوع مسئله چیست؟

# %% [markdown]
# Regression -> زیرا خروجی یک مقدار عددی مانند احتمال بین 0 تا 1 یا 0 تا 100 درصد خواهد بود.

# %% [markdown]
# ### سوال 30
#
# اگر خروجی پروژه گروه‌بندی بیماران باشد، نوع مسئله چیست؟

# %% [markdown]
# Clustering -> زیرا هدف، گروه‌بندی بیماران بدون داشتن برچسب از قبل است.

# %% [markdown]
# ### سوال 31
#
# چه معیارهایی برای ارزیابی مدل اهمیت دارند؟

# %% [markdown]
# Accuracy
#
# Precision
#
# Recall
#
# F1-Score
#
# ROC-AUC (در صورت مناسب بودن نوع مسئله)
#
# Confusion Matrix

# %% [markdown]
# ### سوال 32
#
# چیست و آیا برای این پروژه کافی است؟Accuracy

# %% [markdown]
# Accuracy درصد پیش‌بینی‌های صحیح مدل نسبت به کل نمونه‌ها است.
#
# فرمول:
#
# Accuracy=
# TP+TN+FP+FN/
# TP+TN
# 	​
#
#
# آیا کافی است؟
#
# خیر.
#
# در مسائل پزشکی ممکن است Accuracy بالا باشد اما مدل بیماران واقعی را به‌درستی تشخیص ندهد؛ بنابراین باید معیارهای دیگری مانند Recall و Precision نیز بررسی شوند.

# %% [markdown]
# ### سوال 33
#
# precision چیست؟

# %% [markdown]
# نشان می‌دهد از بین تمام بیمارانی که مدل آن‌ها را بیمار تشخیص داده است، چند نفر واقعاً بیمار بوده‌اند.precision
#
# فرمول:
#
# Precision=
# TP+FP/
# TP
# 	​

# %% [markdown]
# ### سوال 34
#
# Recall چیست؟

# %% [markdown]
# Recall نشان می‌دهد از بین تمام بیماران واقعی، مدل چه تعداد را درست تشخیص داده است.
#
# فرمول:
#
# Recall=
# TP+FN/
# TP
# 	​

# %% [markdown]
# ### سوال 35
#
# در این پروژه Precision مهم‌تر است یا Recall؟ چرا؟

# %% [markdown]
# Recall -> زیرا اگر مدل یک بیمار مبتلا به سرطان را سالم تشخیص دهد (False Negative)، ممکن است درمان او به تأخیر بیفتد و خطرات جدی ایجاد شود. بنابراین کاهش تعداد بیماران از دست‌رفته اهمیت بیشتری دارد.

# %% [markdown]
# ### سوال 36
#
# هزینه False Positive چیست؟

# %% [markdown]
# یعنی مدل یک فرد سالم را بیمار تشخیص دهد.False Positive
#
#
# انجام آزمایش‌های اضافی
#
# افزایش هزینه‌ها
#
# ایجاد استرس برای بیمار
#
# صرف زمان پزشک

# %% [markdown]
# ### سوال 37
#
# هزینه False Negative چیست؟

# %% [markdown]
# یعنی مدل یک بیمار واقعی را سالم تشخیص دهد.False Negative
#
#
# تأخیر در درمان
#
# پیشرفت بیماری
#
# کاهش احتمال درمان موفق
#
# افزایش احتمال مرگ بیمار

# %% [markdown]
# ### سوال 38
#
# کدام خطا برای بیمارستان خطرناک‌تر است؟

# %% [markdown]
# False Negative -> زیرا از دست رفتن یک بیمار مبتلا به سرطان، پیامدهای بسیار جدی‌تری نسبت به انجام چند آزمایش اضافی برای یک فرد سالم دارد.

# %% [markdown]
# ### سوال 39
#
# موفقیت مدل را چگونه تعریف می‌کنید؟

# %% [markdown]
# مدل زمانی موفق است که بتواند بیماران را با دقت بالا طبقه‌بندی کند، Recall مناسبی برای بیماران پرخطر داشته باشد و نتایج آن برای پزشکان قابل اعتماد باشد.

# %% [markdown]
# ### سوال 40
#
# حداقل سه معیار فنی برای موفقیت مدل تعریف کنید.

# %% [markdown]
# Accuracy بیشتر از 90٪
#
# Recall بیشتر از 95٪
#
# F1-Score بیشتر از 90٪

# %% [markdown]
# ### سوال 41
#
# حداقل سه معیار کسب‌وکاری برای موفقیت پروژه تعریف کنید.

# %% [markdown]
# کاهش زمان تشخیص بیماران
#
# کاهش هزینه‌های درمان
#
# افزایش رضایت پزشکان از سیستم
#
# افزایش رضایت بیماران
#
# کاهش خطاهای تشخیص

# %% [markdown]
# ### سوال 42
#
# یک Data Mining Goal Statement رسمی بنویسید.

# %% [markdown]
# هدف داده‌کاوی این پروژه، توسعه یک مدل طبقه‌بندی مبتنی بر یادگیری ماشین برای پیش‌بینی سطح خطر سرطان ریه بیماران (Low، Medium و High) با استفاده از ویژگی‌های بالینی و فردی آن‌ها است تا از این طریق دقت و سرعت تشخیص افزایش یابد.

# %% [markdown]
# ### سوال 43
#
# رابطه بین هدف داده‌کاوی و هدف کسب‌وکار را توضیح دهید.

# %% [markdown]
# هدف کسب‌وکار، بهبود کیفیت خدمات درمانی، کاهش هزینه‌ها و تشخیص زودهنگام سرطان ریه است. هدف داده‌کاوی با ساخت یک مدل دقیق برای پیش‌بینی سطح خطر سرطان ریه، ابزار لازم برای تحقق این اهداف را فراهم می‌کند. بنابراین هدف داده‌کاوی در خدمت دستیابی به هدف کسب‌وکار قرار دارد.

# %% [markdown]
# # بخش چهارم
# # Produce Project Plan

# %% [markdown]
# ### سوال 44
#
# تمام فازهای CRISP-DM را نام ببرید.

# %% [markdown]
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preparation
# 4. Modeling
# 5. Evaluation
# 6. Deployment

# %% [markdown]
# ### سوال 45
#
# برای هر فاز خروجی مورد انتظار را مشخص کنید.

# %% [markdown]
# | فاز                    | خروجی                               |
# | ---------------------- | ----------------------------------- |
# | Business Understanding | اهداف کسب‌وکار، KPIها، برنامه پروژه |
# | Data Understanding     | شناخت داده، کیفیت داده، گزارش EDA   |
# | Data Preparation       | دیتاست آماده مدل‌سازی               |
# | Modeling               | مدل‌های آموزش‌دیده                  |
# | Evaluation             | مقایسه مدل‌ها و انتخاب بهترین مدل   |
# | Deployment             | مدل نهایی و گزارش پروژه             |

# %% [markdown]
# ### سوال 46
#
# چه تخصص‌هایی برای انجام پروژه مورد نیاز است؟

# %% [markdown]
# متخصص علم داده (Data Scientist)
#
# مهندس یادگیری ماشین (ML Engineer)
#
# پزشک متخصص ریه
#
# متخصص انکولوژی
#
# مهندس نرم‌افزار
#
# کارشناس پایگاه داده
#
# مدیر پروژه
#
# کارشناس امنیت اطلاعات

# %% [markdown]
# ### سوال 47
#
# اعضای تیم پروژه را تعریف کنید.

# %% [markdown]
# مدیر پروژه
#
# Data Scientist
#
# Machine Learning Engineer
#
# پزشک متخصص
#
# کارشناس IT
#
# کارشناس پایگاه داده
#
# کارشناس امنیت اطلاعات

# %% [markdown]
# ### سوال 48
#
# مسئولیت هر عضو تیم چیست؟

# %% [markdown]
# | عضو             | مسئولیت          |
# | --------------- | ---------------- |
# | مدیر پروژه      | مدیریت کل پروژه  |
# | پزشک            | اعتبارسنجی نتایج |
# | Data Scientist  | تحلیل داده       |
# | ML Engineer     | ساخت مدل         |
# | Database Admin  | مدیریت داده‌ها   |
# | IT              | استقرار سیستم    |
# | Security Expert | امنیت اطلاعات    |

# %% [markdown]
# ### سوال 49
#
# منابع مورد نیاز پروژه را فهرست کنید.

# %% [markdown]
# دیتاست بیماران
#
# رایانه مناسب
#
# سرور
#
# اینترنت
#
# نیروی متخصص
#
# نرم‌افزارهای تحلیل داده

# %% [markdown]
# ### سوال 50
#
# ابزارهای نرم‌افزاری مورد نیاز پروژه را مشخص کنید.

# %% [markdown]
# Python
#
# Jupyter Notebook
#
# Pandas
#
# NumPy
#
# Matplotlib
#
# Seaborn
#
# Scikit-learn
#
# Git
#
# GitHub
#
# VS Code

# %% [markdown]
# ### سوال 51
#
# یک Timeline برای پروژه طراحی کنید.

# %% [markdown]
# | هفته | فعالیت                   |
# | ---- | ------------------------ |
# | 1    | Business Understanding   |
# | 2    | Data Understanding       |
# | 3    | Data Preparation         |
# | 4    | Modeling                 |
# | 5    | Evaluation               |
# | 6    | Deployment و گزارش نهایی |

# %% [markdown]
# ### سوال 52
#
# وابستگی بین فازهای پروژه را مشخص کنید.

# %% [markdown]
# Business Understanding → Data Understanding → Data Preparation → Modeling → Evaluation → Deployment
#
# هر مرحله پس از تکمیل مرحله قبل آغاز می‌شود.

# %% [markdown]
# ### سوال 53
#
# چه خروجی‌هایی باید به مدیر بیمارستان تحویل داده شود؟

# %% [markdown]
# گزارش مدیریتی
#
# KPIهای پروژه
#
# نتایج عملکرد مدل
#
# تحلیل مزایا و هزینه‌ها
#
# پیشنهادات برای استفاده از سیستم

# %% [markdown]
# ### سوال 54
#
# چه خروجی‌هایی باید به پزشکان تحویل داده شود؟

# %% [markdown]
# مدل نهایی
#
# گزارش عملکرد مدل
#
# Confusion Matrix
#
# Classification Report
#
# راهنمای استفاده از سیستم

# %% [markdown]
# ### سوال 55
#
# معیار پذیرش پروژه توسط کارفرما چیست؟

# %% [markdown]
# دقت مدل مطابق اهداف تعیین‌شده باشد.
#
# مدل روی داده‌های جدید عملکرد مناسبی داشته باشد.
#
# سیستم به‌درستی اجرا شود.
#
# پزشکان و مدیران رضایت داشته باشند.

# %% [markdown]
# ### سوال 56
#
# حداقل 5 ریسک اجرایی پروژه را فهرست کنید.

# %% [markdown]
# 1. تأخیر در دریافت داده‌ها
# 2. کیفیت پایین داده‌ها
# 3. کمبود نیروی متخصص
# 4. مشکلات نرم‌افزاری
# 5. عدم پذیرش سیستم توسط کاربران

# %% [markdown]
# ### سوال 57
#
# برای هر ریسک یک برنامه مقابله تعریف کنید.

# %% [markdown]
# | ریسک              | برنامه مقابله               |
# | ----------------- | --------------------------- |
# | کمبود داده        | جمع‌آوری داده از مراکز دیگر |
# | کیفیت پایین داده  | Data Cleaning               |
# | تأخیر پروژه       | برنامه‌ریزی مجدد            |
# | مشکلات نرم‌افزاری | انجام تست‌های دوره‌ای       |
# | عدم پذیرش کاربران | آموزش و دریافت بازخورد      |

# %% [markdown]
# ### سوال 58
#
# یک جدول Project Plan تهیه کنید.

# %% [markdown]
# | فاز                    | مسئول          | زمان   | خروجی              |
# | ---------------------- | -------------- | ------ | ------------------ |
# | Business Understanding | مدیر پروژه     | ۱ هفته | اهداف پروژه        |
# | Data Understanding     | Data Scientist | ۱ هفته | گزارش داده         |
# | Data Preparation       | Data Scientist | ۱ هفته | دیتاست آماده       |
# | Modeling               | ML Engineer    | ۱ هفته | مدل‌های آموزش‌دیده |
# | Evaluation             | تیم پروژه      | ۱ هفته | بهترین مدل         |
# | Deployment             | IT             | ۱ هفته | سیستم نهایی        |

# %% [markdown]
# ### سوال 59
#
# چه عواملی ممکن است باعث شکست پروژه شوند؟

# %% [markdown]
# کیفیت پایین داده‌ها
#
# کمبود داده
#
# انتخاب مدل نامناسب
#
# نبود همکاری پزشکان
#
# کمبود بودجه
#
# عدم رعایت امنیت اطلاعات
#
# عدم پذیرش کاربران

# %% [markdown]
# ### سوال 60
#
# یک Executive Summary برای مدیرعامل بیمارستان بنویسید.

# %% [markdown]
# این پروژه با هدف توسعه یک سیستم هوشمند برای پیش‌بینی سطح خطر سرطان ریه بیماران انجام شده است. با استفاده از روش CRISP-DM، داده‌های بیماران بررسی، پاک‌سازی و آماده‌سازی شدند و چندین مدل یادگیری ماشین آموزش داده شد. بهترین مدل بر اساس معیارهایی مانند Accuracy، Precision، Recall و F1-Score انتخاب گردید. انتظار می‌رود استفاده از این سیستم به تشخیص سریع‌تر بیماران، کاهش هزینه‌های درمان، افزایش دقت تصمیم‌گیری پزشکان و بهبود کیفیت خدمات درمانی بیمارستان کمک کند.

# %% [markdown]
# # گزارش مدیریتی نهایی

# %% [markdown]
# ## مسئله اصلی کسب‌وکار چیست؟

# %% [markdown]
# تشخیص سریع و دقیق بیماران در معرض خطر سرطان ریه برای کاهش هزینه‌های درمان و افزایش کیفیت خدمات پزشکی.

# %% [markdown]
# ## هدف داده‌کاوی چیست؟

# %% [markdown]
# ساخت یک مدل طبقه‌بندی که بتواند سطح خطر سرطان ریه (Low، Medium، High) را بر اساس اطلاعات بیماران پیش‌بینی کند.

# %% [markdown]
# ## چرا این پروژه ارزش انجام دارد؟

# %% [markdown]
# تشخیص زودهنگام بیماران
#
# کاهش هزینه‌های درمان
#
# افزایش دقت تصمیم‌گیری پزشکان
#
# بهبود کیفیت خدمات درمانی
#
# افزایش رضایت بیماران

# %% [markdown]
# ## مهم‌ترین ریسک‌های پروژه چیست؟

# %% [markdown]
# کیفیت پایین داده‌ها
#
# کمبود داده
#
# عدم اعتماد پزشکان به مدل
#
# نشت اطلاعات بیماران
#
# محدودیت‌های فنی و مالی

# %% [markdown]
# ## معیار موفقیت پروژه چیست؟

# %% [markdown]
# بالاAccuracy
#
# Recall مناسب برای بیماران پرخطر
#
# رضایت پزشکان و مدیران
#
# کاهش زمان تشخیص
#
# کاهش هزینه‌های درمان

# %% [markdown]
# ## برنامه اجرای پروژه چگونه خواهد بود؟

# %% [markdown]
# پروژه مطابق فرآیند CRISP-DM در شش فاز اجرا می‌شود: Business Understanding، Data Understanding، Data Preparation، Modeling، Evaluation و Deployment. پس از آماده‌سازی داده‌ها و آموزش مدل‌ها، بهترین مدل انتخاب شده و در محیط بیمارستان برای کمک به تصمیم‌گیری پزشکان به کار گرفته خواهد شد.
